# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/kinam/git/obds_sep2022/Python_W2/Homo_sapiens.GRCh38.107.gtf', sep='\t', header = None, comment = "#") # Read a tsv file
# Out:
# /var/folders/b_/drg8gqvj38n0vbrfqvqz3k1c0000gn/T/ipykernel_52831/622971896.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/kinam/git/obds_sep2022/Python_W2/Homo_sapiens.GRCh38.107.gtf', sep='\t', header = None, comment = "#") # Read a tsv file

# %%
df.head()
# Out:
#    0               1            2        3        4  5  6  7  \
# 0  1  ensembl_havana         gene  1471765  1497848  .  +  .
# 1  1  ensembl_havana   transcript  1471765  1497848  .  +  .
# 2  1  ensembl_havana         exon  1471765  1472089  .  +  .
# 3  1  ensembl_havana          CDS  1471885  1472089  .  +  0
# 4  1  ensembl_havana  start_codon  1471885  1471887  .  +  0
#
#                                                    8
# 0  gene_id "ENSG00000160072"; gene_version "20"; ...
# 1  gene_id "ENSG00000160072"; gene_version "20"; ...
# 2  gene_id "ENSG00000160072"; gene_version "20"; ...
# 3  gene_id "ENSG00000160072"; gene_version "20"; ...
# 4  gene_id "ENSG00000160072"; gene_version "20"; ...

# %%
df.columns = ['seqname', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame', 'group']

# %%
df.head()
# Out:
#   seqname          source      feature    start      end score strand frame  \
# 0       1  ensembl_havana         gene  1471765  1497848     .      +     .
# 1       1  ensembl_havana   transcript  1471765  1497848     .      +     .
# 2       1  ensembl_havana         exon  1471765  1472089     .      +     .
# 3       1  ensembl_havana          CDS  1471885  1472089     .      +     0
# 4       1  ensembl_havana  start_codon  1471885  1471887     .      +     0
#
#                                                group
# 0  gene_id "ENSG00000160072"; gene_version "20"; ...
# 1  gene_id "ENSG00000160072"; gene_version "20"; ...
# 2  gene_id "ENSG00000160072"; gene_version "20"; ...
# 3  gene_id "ENSG00000160072"; gene_version "20"; ...
# 4  gene_id "ENSG00000160072"; gene_version "20"; ...

# %%
df.shape
# Out:
# (3371244, 9)

# %%
len(df['source'].unique())
# Out:
# 8

# %%
ens_df = df.query("source == 'ensembl_havana'")

# %%
ens_df.shape
# Out:
# (714608, 9)

# %%
ens_df.head()
# Out:
#   seqname          source      feature    start      end score strand frame  \
# 0       1  ensembl_havana         gene  1471765  1497848     .      +     .
# 1       1  ensembl_havana   transcript  1471765  1497848     .      +     .
# 2       1  ensembl_havana         exon  1471765  1472089     .      +     .
# 3       1  ensembl_havana          CDS  1471885  1472089     .      +     0
# 4       1  ensembl_havana  start_codon  1471885  1471887     .      +     0
#
#                                                group
# 0  gene_id "ENSG00000160072"; gene_version "20"; ...
# 1  gene_id "ENSG00000160072"; gene_version "20"; ...
# 2  gene_id "ENSG00000160072"; gene_version "20"; ...
# 3  gene_id "ENSG00000160072"; gene_version "20"; ...
# 4  gene_id "ENSG00000160072"; gene_version "20"; ...

# %%
df.groupby("feature").count()
# Out:
#                  seqname   source    start      end    score   strand  \
# feature
# CDS               871196   871196   871196   871196   871196   871196
# Selenocysteine       119      119      119      119      119      119
# exon             1624585  1624585  1624585  1624585  1624585  1624585
# five_prime_utr    171504   171504   171504   171504   171504   171504
# gene               61860    61860    61860    61860    61860    61860
# start_codon        96934    96934    96934    96934    96934    96934
# stop_codon         90724    90724    90724    90724    90724    90724
# three_prime_utr   203201   203201   203201   203201   203201   203201
# transcript        251121   251121   251121   251121   251121   251121
#
#                    frame    group
# feature
# CDS               871196   871196
# Selenocysteine       119      119
# exon             1624585  1624585
# five_prime_utr    171504   171504
# gene               61860    61860
# start_codon        96934    96934
# ...

# %%
genes = df.query("feature == 'gene'")

# %%
genes.shape
# Out:
# (61860, 9)

# %%
genes.head()
# Out:
#     seqname          source feature    start      end score strand frame  \
# 0         1  ensembl_havana    gene  1471765  1497848     .      +     .
# 107       1          havana    gene  2212523  2220738     .      +     .
# 111       1          havana    gene   629062   629433     .      +     .
# 114       1          havana    gene  8786211  8786913     .      -     .
# 117       1          havana    gene   634376   634922     .      +     .
#
#                                                  group
# 0    gene_id "ENSG00000160072"; gene_version "20"; ...
# 107  gene_id "ENSG00000234396"; gene_version "3"; g...
# 111  gene_id "ENSG00000225972"; gene_version "1"; g...
# 114  gene_id "ENSG00000224315"; gene_version "2"; g...
# 117  gene_id "ENSG00000198744"; gene_version "5"; g...

# %%
# genes['gene_length'] = genes.iloc[:,4] - genes.iloc[:,3]
# Out:
# /var/folders/b_/drg8gqvj38n0vbrfqvqz3k1c0000gn/T/ipykernel_52831/3297691938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genes['gene_length'] = genes.iloc[:,4] - genes.iloc[:,3]

# %%
genes = genes.assign(gene_length = genes["end"] - genes["start"])

# %%
genes.shape
# Out:
# (61860, 10)

# %%
genes.head()
# Out:
#     seqname          source feature    start      end score strand frame  \
# 0         1  ensembl_havana    gene  1471765  1497848     .      +     .
# 107       1          havana    gene  2212523  2220738     .      +     .
# 111       1          havana    gene   629062   629433     .      +     .
# 114       1          havana    gene  8786211  8786913     .      -     .
# 117       1          havana    gene   634376   634922     .      +     .
#
#                                                  group  gene_length
# 0    gene_id "ENSG00000160072"; gene_version "20"; ...        26083
# 107  gene_id "ENSG00000234396"; gene_version "3"; g...         8215
# 111  gene_id "ENSG00000225972"; gene_version "1"; g...          371
# 114  gene_id "ENSG00000224315"; gene_version "2"; g...          702
# 117  gene_id "ENSG00000198744"; gene_version "5"; g...          546

# %%
mean_length = genes["gene_length"].mean()

# %%
median_length = genes["gene_length"].median()

# %%
mean_length
# Out:
# 32626.786744261233

# %%
median_length
# Out:
# 3553.5

# %%
genes.head()
# Out:
#     seqname          source feature    start      end score strand frame  \
# 0         1  ensembl_havana    gene  1471765  1497848     .      +     .
# 107       1          havana    gene  2212523  2220738     .      +     .
# 111       1          havana    gene   629062   629433     .      +     .
# 114       1          havana    gene  8786211  8786913     .      -     .
# 117       1          havana    gene   634376   634922     .      +     .
#
#                                                  group  gene_length
# 0    gene_id "ENSG00000160072"; gene_version "20"; ...        26083
# 107  gene_id "ENSG00000234396"; gene_version "3"; g...         8215
# 111  gene_id "ENSG00000225972"; gene_version "1"; g...          371
# 114  gene_id "ENSG00000224315"; gene_version "2"; g...          702
# 117  gene_id "ENSG00000198744"; gene_version "5"; g...          546

# %%
genes_sorted = genes.sort_values(by = ['gene_length'])

# %%
genes_sorted.head()
# Out:
#         seqname  source feature      start        end score strand frame  \
# 2341061      14  havana    gene   22438547   22438554     .      +     .
# 2341642      14  havana    gene   22439007   22439015     .      +     .
# 2418605      14  havana    gene  105865551  105865561     .      -     .
# 1312465       7  havana    gene  142786213  142786224     .      +     .
# 2341080      14  havana    gene   22449113   22449125     .      +     .
#
#                                                      group  gene_length
# 2341061  gene_id "ENSG00000223997"; gene_version "1"; g...            7
# 2341642  gene_id "ENSG00000237235"; gene_version "2"; g...            8
# 2418605  gene_id "ENSG00000236597"; gene_version "1"; g...           10
# 1312465  gene_id "ENSG00000282431"; gene_version "1"; g...           11
# 2341080  gene_id "ENSG00000228985"; gene_version "1"; g...           12

# %%
genes_sorted.iloc[0:20,:]
# Out:
#         seqname  source feature      start        end score strand frame  \
# 2341061      14  havana    gene   22438547   22438554     .      +     .
# 2341642      14  havana    gene   22439007   22439015     .      +     .
# 2418605      14  havana    gene  105865551  105865561     .      -     .
# 1312465       7  havana    gene  142786213  142786224     .      +     .
# 2341080      14  havana    gene   22449113   22449125     .      +     .
# 2418657      14  havana    gene  105894508  105894523     .      -     .
# 2418681      14  havana    gene  105903616  105903631     .      -     .
# 2418713      14  havana    gene  105913222  105913237     .      -     .
# 2418701      14  havana    gene  105909907  105909923     .      -     .
# 2462756      15  havana    gene   20011153   20011169     .      -     .
# 2418669      14  havana    gene  105900638  105900654     .      -     .
# 2467826      15  havana    gene   21017800   21017816     .      -     .
# ...

# %%
genes_sorted = genes.sort_values(by = ['gene_length'], ascending = False)

# %%
genes_sorted.head()
# Out:
#         seqname          source feature      start        end score strand  \
# 2679474      16  ensembl_havana    gene    5239802    7713340     .      +
# 1297140       7  ensembl_havana    gene  146116002  148420998     .      +
# 1733179       9  ensembl_havana    gene    8314246   10613002     .      -
# 1514121       X  ensembl_havana    gene   31097677   33339609     .      -
# 1850816      11  ensembl_havana    gene   83455012   85627922     .      -
#
#         frame                                              group  gene_length
# 2679474     .  gene_id "ENSG00000078328"; gene_version "23"; ...      2473538
# 1297140     .  gene_id "ENSG00000174469"; gene_version "23"; ...      2304996
# 1733179     .  gene_id "ENSG00000153707"; gene_version "19"; ...      2298756
# 1514121     .  gene_id "ENSG00000198947"; gene_version "18"; ...      2241932
# 1850816     .  gene_id "ENSG00000150672"; gene_version "18"; ...      2172910

# %%
genes_sorted.iloc[0:10,:]
# Out:
#         seqname          source feature      start        end score strand  \
# 2679474      16  ensembl_havana    gene    5239802    7713340     .      +
# 1297140       7  ensembl_havana    gene  146116002  148420998     .      +
# 1733179       9  ensembl_havana    gene    8314246   10613002     .      -
# 1514121       X  ensembl_havana    gene   31097677   33339609     .      -
# 1850816      11  ensembl_havana    gene   83455012   85627922     .      -
# 1601567       8  ensembl_havana    gene    2935353    4994972     .      -
# 3030998      20  ensembl_havana    gene   13995369   16053197     .      +
# 1104549       6  ensembl_havana    gene   63719980   65707226     .      -
# 338522        2          havana    gene  140231423  142131016     .      -
# 2041854      10  ensembl_havana    gene   65912457   67763637     .      -
#
#         frame                                              group  gene_length
# ...

# %%
group_split = genes["group"].str.split(";", expand = True)

# %%
group_split.head()
# Out:
#                              0                   1                      2  \
# 0    gene_id "ENSG00000160072"   gene_version "20"     gene_name "ATAD3B"
# 107  gene_id "ENSG00000234396"    gene_version "3"   gene_source "havana"
# 111  gene_id "ENSG00000225972"    gene_version "1"   gene_name "MTND1P23"
# 114  gene_id "ENSG00000224315"    gene_version "2"     gene_name "RPL7P7"
# 117  gene_id "ENSG00000198744"    gene_version "5"   gene_name "MTCO3P12"
#
#                                  3                                       4  \
# 0     gene_source "ensembl_havana"           gene_biotype "protein_coding"
# 107          gene_biotype "lncRNA"
# 111           gene_source "havana"   gene_biotype "unprocessed_pseudogene"
# 114           gene_source "havana"     gene_biotype "processed_pseudogene"
# 117           gene_source "havana"   gene_biotype "unprocessed_pseudogene"
#
#         5
# 0
# 107  None
# 111
# 114
# 117

# %%
genes.reset_index()
# Out:
#          index     seqname          source feature    start      end score  \
# 0            0           1  ensembl_havana    gene  1471765  1497848     .
# 1          107           1          havana    gene  2212523  2220738     .
# 2          111           1          havana    gene   629062   629433     .
# 3          114           1          havana    gene  8786211  8786913     .
# 4          117           1          havana    gene   634376   634922     .
# ...        ...         ...             ...     ...      ...      ...   ...
# 61855  3371150  KI270711.1         ensembl    gene     4612    29626     .
# 61856  3371224  KI270713.1         ensembl    gene    30437    30580     .
# 61857  3371227  KI270713.1         ensembl    gene    35407    35916     .
# 61858  3371233  KI270713.1         ensembl    gene    31698    32528     .
# 61859  3371241  KI270713.1         ensembl    gene    21861    22024     .
#
# ...

# %%
merged_df = group_split.merge(genes, left_index = True, right_index = True,  how = "inner")

# %%
merged_df.head()
# Out:
#                              0                   1                      2  \
# 0    gene_id "ENSG00000160072"   gene_version "20"     gene_name "ATAD3B"
# 107  gene_id "ENSG00000234396"    gene_version "3"   gene_source "havana"
# 111  gene_id "ENSG00000225972"    gene_version "1"   gene_name "MTND1P23"
# 114  gene_id "ENSG00000224315"    gene_version "2"     gene_name "RPL7P7"
# 117  gene_id "ENSG00000198744"    gene_version "5"   gene_name "MTCO3P12"
#
#                                  3                                       4  \
# 0     gene_source "ensembl_havana"           gene_biotype "protein_coding"
# 107          gene_biotype "lncRNA"
# 111           gene_source "havana"   gene_biotype "unprocessed_pseudogene"
# 114           gene_source "havana"     gene_biotype "processed_pseudogene"
# 117           gene_source "havana"   gene_biotype "unprocessed_pseudogene"
#
#         5 seqname          source feature    start      end score strand  \
# ...

# %%
merged_df_1 = genes.merge(ens_df, on = ["seqname", "end", "start"], how = "inner")

# %%
merged_df_1.head()
# Out:
#   seqname        source_x feature_x    start      end score_x strand_x  \
# 0       1  ensembl_havana      gene  1471765  1497848       .        +
# 1       1  ensembl_havana      gene  1471765  1497848       .        +
# 2       1  ensembl_havana      gene  3069168  3438621       .        +
# 3       1  ensembl_havana      gene  2403964  2413797       .        -
# 4       1  ensembl_havana      gene  2228319  2310213       .        +
#
#   frame_x                                            group_x  gene_length  \
# 0       .  gene_id "ENSG00000160072"; gene_version "20"; ...        26083
# 1       .  gene_id "ENSG00000160072"; gene_version "20"; ...        26083
# 2       .  gene_id "ENSG00000142611"; gene_version "17"; ...       369453
# 3       .  gene_id "ENSG00000157911"; gene_version "11"; ...         9833
# 4       .  gene_id "ENSG00000157933"; gene_version "10"; ...        81894
#
#          source_y   feature_y score_y strand_y frame_y  \
# ...
